# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

f_app = os.path.expanduser('~/Desktop/application_train.csv')
h_app = os.path.expanduser('~/Desktop/HomeCredit_columns_description.csv')
app_train = pd.read_csv(f_app)
app_home = pd.read_csv(h_app,encoding='unicode_escape')

app_train.head()
#app_home.head()

#由此可得知總收入並無奇異值
(app_train['AMT_INCOME_TOTAL']/10000).describe()
plt.hist(app_train['AMT_INCOME_TOTAL'])
plt.show()

(app_train['AMT_CREDIT']/10000).describe()
plt.hist(app_train['AMT_CREDIT'])
plt.show()
app_train['AMT_CREDIT'].value_counts()
# Out:
# 450000.0     9709
# 675000.0     8877
# 225000.0     8162
# 180000.0     7342
# 270000.0     7241
# 900000.0     6246
# 254700.0     4500
# 545040.0     4437
# 808650.0     4152
# 135000.0     3660
# 755190.0     3524
# 1125000.0    3493
# 521280.0     3175
# 284400.0     3096
# 1078200.0    2856
# 454500.0     2649
# 1288350.0    2613
# 269550.0     2463
# 202500.0     2339
# 781920.0     2328
# 1350000.0    2321
# 239850.0     2084
# 315000.0     2072
# 247500.0     2057
# 640080.0     2041
# 1006920.0    1883
# 540000.0     1821
# 360000.0     1743
# 508495.5     1717
# 592560.0     1688
#              ...
# 1639431.0       1
# 1242531.0       1
# 1649853.0       1
# 618903.0        1
# 1114011.0       1
# 1650771.0       1
# 207504.0        1
# 414981.0        1
# 829512.0        1
# 829440.0        1
# 2116395.0       1
# 308475.0        1
# 1234741.5       1
# 1234863.0       1
# 192024.0        1
# 1235344.5       1
# 828895.5        1
# 1657669.5       1
# 1407456.0       1
# ...
